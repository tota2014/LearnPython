# %% [markdown]
# <a href="https://colab.research.google.com/github/tota2014/LearnPython/blob/master/01base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %%
# %timeit [i**2 for i  in range(1000)]
# Out:
# 69.5 µs ± 591 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
L=[]
for n in range(1000):
  L.append(n**2)
# Out:
# 84.8 µs ± 11.4 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
salary=100000

# %%
salary
# Out:
# 100000

# %%
base_salary=100000
bonus_rate=.10

# %%
total_salary=(base_salary)*(1+bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001

# %%
lukes_salary = 100000

# %%
Company_name='DataWiz Inc'

# %%
Company_name
# Out:
# 'DataWiz Inc'

# %%
job_wfh=True#工作为居家办公模式

# %%
job_wfh
# Out:
# True

# %%
job_id=101
job_titlle='Data Analyst'
job_salary=125000

# %%
print("Date Job Description")
print("++++++++++++++++++++++")
print("Job id：   ",job_id)
print("Company Name：   ",Company_name)
print("Job Title：   ",job_titlle)
print("salary：   ",job_salary)
print("WFH   ",job_wfh)
# Out:
# Date Job Description
# ++++++++++++++++++++++
# Job id：    101
# Company Name：    DataWiz Inc
# Job Title：    Data Analyst
# salary：    125000
# WFH    True
